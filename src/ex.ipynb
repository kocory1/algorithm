# %%
a = 5
b = 6 
c = a+b
print(c)
# Out:
# 11

# %%
myList = [1,2,3,4,5]

myList.append(6)
myList.append(7)
myList.append(8)
myList.append(9)

print(myList.pop())

myList.reverse()
print(myList.pop())
print(myList)
# Out:
# 9
# 1
# [8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# ## Example 1

# %%
given_range = 10
for i in range(given_range):
    if (i % 2 == 0):
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ## Example2

# %%
given_number = 129475

print(len(str(given_number)))
# Out:
# 6

# %% [markdown]
# ## Example3

# %%
given_string = input()

print(given_string[::-1])
# Out:
# miK

# %% [markdown]
# ## Example4

# %%
for i in range(5,0,-1):
    for j in range(i):
        print(i, end = " ")
    print()
# Out:
# 5 5 5 5 5
# 4 4 4 4
# 3 3 3
# 2 2
# 1

# %%
for i in range(5,0,-1):
    print(str(i) * i)
# Out:
# 55555
# 4444
# 333
# 22
# 1
